# %% [markdown]
# <a href="https://colab.research.google.com/github/Hallymhwangbo/2020-AI_minseo/blob/master/02_svm_hbms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_circles

# %% [markdown]
# 데이터 만들기

# %%
X, Y = (make_circles(n_samples=500, noise = 0.02))

# %%
X.shape
# Out:
# (500, 2)

# %%
Y.shape
# Out:
# (500,)

# %%
Y[:10]
# Out:
# array([1, 0, 0, 1, 1, 1, 1, 1, 0, 1])

# %%
x1 = X[:, 0]
x2 = X[:, 1]

# %%
plt.scatter(x1, x2, c=Y)
plt.grid('on')
plt.axis('equal')
# Out:
# (-1.138191866289734,
#  1.1360536019115497,
#  -1.1306495927033584,
#  1.1297206985043582)

# %% [markdown]
# 다른 하나의 축을 만들어서 3d로 보기

# %% [markdown]
# $$x3 = x1^2 + x2^2$$

# %%
x3 = x1**2 + x2**2

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x1, x2, x3, c=Y)

# %% [markdown]
# ##SVM 테스트 #1

# %%
from sklearn.svm import SVC
model1 = SVC(kernel ='linear')

# %%
model1.fit(X, Y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
def PlotSVM2D(X, y, model, title="SVM", xmin=-2, xmax=2, ymin=-2, ymax=2):
    import matplotlib as mpl
    XX, YY = np.meshgrid(np.arange(xmin, xmax, (xmax-xmin)/1000),
                         np.arange(ymin, ymax, (ymax-ymin)/1000))
    ZZ = np.reshape(model.predict(
        np.array([XX.ravel(), YY.ravel()]).T), XX.shape)
    fig = plt.figure(figsize=(5,5))
    plt.contourf(XX, YY, ZZ, cmap=mpl.cm.Paired_r, alpha=0.5)
    plt.scatter(X[:, 0], X[:, 1], c=y)
    plt.xlim(xmin, xmax)
    plt.ylim(ymin, ymax)
    plt.title(title)
    plt.xlabel("x1")
    plt.ylabel("x2")

# %%
PlotSVM2D(X, Y, model=model1, title='Linear SVM')

# %% [markdown]
# 결과: 선형으로 나누기는 원형의 데이터를 레이블 별로 나눌 수 없었다.

# %% [markdown]
# ## SVM 테스트 #2

# %%
X.shape
# Out:
# (500, 2)

# %% [markdown]
# 축을 하나 더 만들었음

# %%
X2 = np.vstack((x1, x2, x3)).T

# %%
X2.shape
# Out:
# (500, 3)

# %%
model2 = SVC(kernel ='linear')

# %%
model2.fit(X2, Y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
def PlotSVM3D(X, Y, model):
  import numpy as np
  X1 = X[:, 0]
  X2 = X[:, 1]
  X3 = X[:, 2]
  w = model.coef_ 
  b = model.intercept_ 

  x1, x2 = np.meshgrid(X1, X2) 
  x3 = -(w[0][0]*x1 + w[0][1]*x2 + b) / w[0][2] 

  fig = plt.figure() 
  axes2 = fig.add_subplot(111, projection = '3d') 
  axes2.scatter(X1, X2, X3, c = Y) 
  axes1 = fig.gca(projection = '3d') 
  axes1.plot_surface(x1, x2, x3, alpha = 0.01) 
  #plt.show()

# %%
PlotSVM3D(X2, Y, model=model2)

# %% [markdown]
# 결과: test#1과 마찬가지로 선형으로 나눴지만, 축을 하나 더 생성하여 3d의 형태로 만들어
# 데이터를 잘 나눴다.

# %% [markdown]
# ## SVM 테스트 #3

# %%
model3 = SVC(kernel ='rbf')

# %%
model3.fit(X, Y)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
PlotSVM2D(X, Y, model=model3, title='RBF SVM')

# %% [markdown]
# 결과: test#1과 같이 평면의 형태이지만, 데이터가 잘 나눠졌다. RBF사용
